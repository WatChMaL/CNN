# %%
import os
import sys

par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)

# %%
import numpy as np

# %% [markdown]
# # Using results from the latest validation run

# %%
softmax5 = np.load("softmax5.npy")
label5 = np.load("label5.npy")
prediction5 = np.load("prediction5.npy")

# %%
gamma_softmax = softmax5[label5 == 0,:]
electron_softmax = softmax5[label5 == 1,:]
muon_softmax = softmax5[label5 == 2,:]

# %%
print("gamma softmax shape : ", gamma_softmax.shape)
print("electron softmax shape : ", electron_softmax.shape)
print("muon softmax shape : ", muon_softmax.shape)
# Out:
# gamma softmax shape :  (30012, 3)
# electron softmax shape :  (29938, 3)
# muon softmax shape :  (30050, 3)

# %% [markdown]
# Why do the number of gamma, electron, muon events have the same number as before ?
#
#     Is the seed fixed s.t. the random sampling is fixed ?

# %%
from plot_utils.plot_utils import plot_softmax_curve
label_dict_1 = {"gamma":0, "electron":1}
label_dict_2 = {"gamma":0, "muon":2}
label_dict_3 = {"electron":1, "muon":2}
bw = 0.1

# %% [markdown]
# # Plot the softmax curve for different pairs

# %%
plot_softmax_curve(softmax5, label5, labels_dict=label_dict_1, particle="gamma")
# Out:
# (30012, 3)

# %%
plot_softmax_curve(softmax5, label5, labels_dict=label_dict_2, particle="gamma")
# Out:
# (30012, 3)

# %%
plot_softmax_curve(softmax5, label5, labels_dict=label_dict_1, particle="electron")
# Out:
# (29938, 3)

# %%
plot_softmax_curve(softmax5, label5, labels_dict=label_dict_3, particle="electron")
# Out:
# (29938, 3)

# %%
plot_softmax_curve(softmax5, label5, labels_dict=label_dict_2, particle="muon")
# Out:
# (30050, 3)

# %%
plot_softmax_curve(softmax5, label5, labels_dict=label_dict_3, particle="muon")
# Out:
# (30050, 3)

# %% [markdown]
# # Plot the ROC curve

# %%
from plot_utils.plot_utils import plot_ROC_curve

# %%
print(label5.shape)
print(softmax5.shape)
# Out:
# (90000,)
# (90000, 3)

# %%
class_dict = {0:"gamma", 1:"electron", 2:"muon"}

# %%
plot_ROC_curve(softmax5, label5, class_dict)
