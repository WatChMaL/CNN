# %% [markdown]
# # CNN Performance Analysis

# %%
# Python library and module imports
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the custom plotting module
from plot_utils import plot_utils

# Validation run number
run = 6

# Load the np array from the disk into memory
softmaxes = np.load("softmax" + str(run) + ".npy")
labels = np.load("labels" + str(run) + ".npy")
predictions = np.load("predictions" + str(run) + ".npy")
energies = np.load("energies" + str(run) + ".npy")

# Reshape the deformed arrays
energies = energies.reshape(energies.shape[0]*energies.shape[1], -1)

# Validate the shapes of the loaded array
print("softmaxes shape : ", softmaxes.shape)
print("labels shape : ", labels.shape)
print("predictions shape : ", predictions.shape)
print("energies shape : ", energies.shape)
# Out:
# softmaxes shape :  (90000, 3)
# labels shape :  (90000,)
# predictions shape :  (90000,)
# energies shape :  (90000, 1)

# %%
plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1},
                                     particle="e", thresholds=[0.2, 0.5, 0.8], energy_interval=5,
                                     energy_min=100, energy_max = 1000, num_bins=100, save_path=None)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2fee1b7d7f3d> in <module>
#       1 plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1},
#       2                                      particle="e", thresholds=[0.2, 0.5, 0.8], energy_interval=5,
# ----> 3                                      energy_min=100, energy_max = 1000, num_bins=100, save_path=None)
#
# ~/WatChMaL/CNN/plot_utils/plot_utils.py in plot_background_rejection(softmax, labels, energies, index_dict, particle, thresholds, energy_interval, energy_min, energy_max, num_bins, save_path)
#     556                                                           {particle:index_dict[particle]},
#     557                                                           energy_lower, energy_upper,
# ...

# %%
plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1},
                                     particle="e", thresholds=[0.2, 0.5, 0.8], energy_interval=25,
                                     energy_min=100, energy_max = 1000, num_bins=100, save_path=None)

# %%
plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1},
                                     particle="e", thresholds=[0.2, 0.5, 0.8], energy_interval=50,
                                     energy_min=100, energy_max = 1000, num_bins=100, save_path=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-49c38e4ea431> in <module>
#       1 plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1},
#       2                                      particle="e", thresholds=[0.2, 0.5, 0.8], energy_interval=50,
# ----> 3                                      energy_min=100, energy_max = 1000, num_bins=100, save_path=None)
#
# ...

# %%
plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1, "mu":2},
                                     particle="e", threshold=0.75, energy_interval=5, energy_min=100,
                                     num_bins=100, save_path=None)

# %%
plot_utils.plot_signal_efficiency(softmaxes, labels, energies, index_dict={"e":1},
                                     particle="e", thresholds=[0.2, 0.5, 0.8], energy_interval=50,
                                     energy_min=100, energy_max = 1000, num_bins=100, save_path=None)

# %%
plot_utils.plot_signal_efficiency(softmaxes, labels, energies, index_dict={"e":1}, particle="e",
                                  threshold=0.5, energy_interval=5, energy_min=100, num_bins=100,
                                  save_path=None)

# %%
plot_utils.plot_signal_efficiency(softmaxes, labels, energies, index_dict={"e":1}, particle="e",
                                  threshold=0.75, energy_interval=5, energy_min=100, num_bins=100,
                                  save_path=None)

# %% [markdown]
# # Improving the plots with suggestion from Patrick

# %%
plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1, "mu":2},
                                     particle="e", threshold=0.75, energy_interval=25, energy_min=100,
                                     num_bins=100, save_path=None)

# %%
plot_utils.plot_background_rejection(softmaxes, labels, energies, index_dict={"gamma":0, "e":1, "mu":2},
                                     particle="e", threshold=0.75, energy_interval=50, energy_min=100,
                                     num_bins=100, save_path=None)
