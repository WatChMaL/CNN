# %% [markdown]
# # June 12 - Periodicty Analysis

# %%
# Python library and module imports
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
import h5py
import torch
from matplotlib.colors import LogNorm
import pandas as pd
import random

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the custom plotting module
from plot_utils import plot_utils

# %% [markdown]
# ## Using 50000 samples

# %%
# Setup the paths to the log files

log = "20190613_011139"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using Adam(lr=0.0001)"],
                              {"ResNet18 using Adam(lr=0.0001)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.5))

# %%
# Setup the paths to the log files

log = "20190613_022606"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using Adam(lr=0.00001)"],
                              {"ResNet18 using Adam(lr=0.00001)":["red","blue"]},
                              downsample_interval=32, show_plot=False)

# %%
# Setup the paths to the log files

log = "20190613_024007"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using Adam(lr=0.000001)"],
                              {"ResNet18 using Adam(lr=0.000001)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.2))

# %%
# Setup the paths to the log files

log = "20190613_020658"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using AdaGrad (lr=0.01)"],
                              {"ResNet18 using AdaGrad (lr=0.01)":["red","blue"]},
                              downsample_interval=32, show_plot=False)

# %%
# Setup the paths to the log files

log = "20190613_011854"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using AdaGrad (lr=0.0001)"],
                              {"ResNet18 using AdaGrad (lr=0.0001)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.2))

# %%
# Setup the paths to the log files

log = "20190613_022403"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using SGD (lr=0.01)"],
                              {"ResNet18 using SGD (lr=0.01)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.5))

# %%
# Setup the paths to the log files

log = "20190613_011608"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using SGD (lr=0.0001)"],
                              {"ResNet18 using SGD (lr=0.0001)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.2))

# %% [markdown]
# ## Using 100000 samples

# %%
# Setup the paths to the log files

log = "20190613_014158"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 (using Adam)"],
                              {"ResNet18 (using Adam)":["red","blue"]},
                              downsample_interval=32, show_plot=False)

# %%
# Setup the paths to the log files

log = "20190613_014259"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 (using AdaGrad)"],
                              {"ResNet18 (using AdaGrad)":["red","blue"]},
                              downsample_interval=32, show_plot=False)

# %%
# Setup the paths to the log files

log = "20190613_014335"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 (using SGD)"],
                              {"ResNet18 (using SGD)":["red","blue"]},
                              downsample_interval=32, show_plot=False)

# %% [markdown]
# # AdaGrad with a higher learning rate ( lr = 0.01 )

# %%
# Setup the paths to the log files

log = "20190613_020658"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 (using AdaGrad)"],
                              {"ResNet18 (using AdaGrad)":["red","blue"]},
                              downsample_interval=32, show_plot=False)

# %% [markdown]
# ## SGD with a higher learning rate ( lr = 0.01 )

# %%
# Setup the paths to the log files

log = "20190613_022403"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 (using SGD)"],
                              {"ResNet18 (using SGD)":["red","blue"]},
                              downsample_interval=32, show_plot=False)

# %% [markdown]
# ## Adam with a lower learning rate ( lr = 0.00001 )

# %%
# Setup the paths to the log files

log = "20190613_022606"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 (using Adam)"],
                              {"ResNet18 (using Adam)":["red","blue"]},
                              downsample_interval=32, show_plot=False)
