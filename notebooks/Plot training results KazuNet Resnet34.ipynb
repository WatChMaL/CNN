# %%
# Python library and module imports
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
import h5py
import torch
from matplotlib.colors import LogNorm
import pandas as pd

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the custom plotting module
from plot_utils import plot_utils

# %%
# %matplotlib inline

# %% [markdown]
# This is Kazunet lr 1e-4

# %%
# !cat /home/wfedorko/VAE/dumps/20190618_104545/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  6 7
# load = test_kazunet
# lr = 0.0001
# model =  kazunet KazuNet
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190618_104545/log_train.csv","/home/wfedorko/VAE/dumps/20190618_104545/val_test.csv")

# %%
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_104545/log_train.csv",window=400)

# %%
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_104545/val_test.csv",window=40,sample_title='validation')

# %% [markdown]
# This is Resnet34 lr 1e-4

# %%
# !cat /home/wfedorko/VAE/dumps/20190618_161337/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  6 7
# load = test_resnet_w
# lr = 0.0001
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
# !ls /home/wfedorko/VAE/dumps/20190618_161337
# Out:
# config_file.ini  labels.npy	predictions.npy  resnet34BEST.pth  val_test.csv
# energies.npy	 log_train.csv	resnet34.pth	 softmax.npy

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190618_161337/log_train.csv","/home/wfedorko/VAE/dumps/20190618_161337/val_test.csv")

# %%
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_161337/log_train.csv",window=100)

# %%
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_161337/val_test.csv",window=40,sample_title='validation')

# %% [markdown]
#    - kazunet 50k
#    - Resnet34 1 GPU
#    - Resnet34 1 GPU SGD <--
#    - remove detach
#    - downgrade pytorch??

# %% [markdown]
# !ls

# %% [markdown]
# This is resnet34 SGD single GPU lr 1e-4

# %%
# !cat ../dumps/20190618_235149/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  6
# load = test_resnet_w
# lr = 0.0001
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190618_235149/log_train.csv","/home/wfedorko/VAE/dumps/20190618_235149/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_235149/log_train.csv",window=40)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_235149/val_test.csv",window=40,sample_title="validation")

# %% [markdown]
# This is resnet34 SGD single GPU lr 1e-3

# %%
# !cat ../dumps/20190618_235454/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  7
# load = test_resnet_w_1em3
# lr = 0.001
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190618_235454/log_train.csv","/home/wfedorko/VAE/dumps/20190618_235454/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_235454/log_train.csv",window=100)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190618_235454/val_test.csv",window=40,sample_title="validation")

# %% [markdown]
# This is resnet34 SGD 1e-2

# %%
# !cat ../dumps/20190619_064705/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  3
# load = test_resnet_w_1em2
# lr = 0.01
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190619_064705/log_train.csv","/home/wfedorko/VAE/dumps/20190619_064705/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190619_064705/log_train.csv",window=100)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190619_064705/val_test.csv",window=40,sample_title="validation")

# %% [markdown]
# This is Resnet 34 SGD ls 1e-2 single GPU AFTER DOWNGRADE

# %%
# !cat ../dumps/20190621_062137/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  0
# load = test_resnet_w_1em2
# lr = 0.01
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190621_062137/log_train.csv","/home/wfedorko/VAE/dumps/20190621_062137/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190621_062137/log_train.csv",window=100)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190621_062137/val_test.csv",window=40,sample_title="validation")

# %% [markdown]
# This is Resnet34 SGD ls 1e-2 2 GPUs AFTER DOWNGRADE

# %%
cat ../dumps/20190621_071756/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  1 2
# load = test_resnet_w_1em2_2gpu
# lr = 0.01
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190621_071756/log_train.csv","/home/wfedorko/VAE/dumps/20190621_071756/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190621_071756/log_train.csv",window=100)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190621_071756/val_test.csv",window=40,sample_title="validation")

# %% [markdown]
# This is Resnet 34 SGD ls 1e-2 single GPU AFTER **UP**GRADE

# %%
# !cat ../dumps/20190711_032216/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  0
# load = test_resnet_w_1em2
# lr = 0.01
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190711_032216/log_train.csv","/home/wfedorko/VAE/dumps/20190711_032216/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190711_032216/log_train.csv",window=100)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190711_032216/val_test.csv",window=40,sample_title="validation")

# %%
from io_utils.custom_samplers import SubsetSequenceSampler

# %%
indices=np.asarray([9,1,8,2,7,3,6,4,5,0])

# %%
sampler=SubsetSequenceSampler(indices)

# %%
for i, ind in enumerate(sampler):
    print(i,ind)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-32bdeb847858> in <module>
# ----> 1 for i, ind in enumerate(sampler):
#       2     print(i,ind)
#
# TypeError: iter() returned non-iterator of type 'numpy.ndarray'

# %%
it=iter(indices)

# %%
it=(indices[i] for i in range(len(indices)))

# %%
next(it)
# Out:
# 9

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-25-bc1ab118995a> in <module>
# ----> 1 next(it)
#
# StopIteration:

# %%
for i, idx in enumerate(it):
    print(i,idx)
# Out:
# 0 9
# 1 1
# 2 8
# 3 2
# 4 7
# 5 3
# 6 6
# 7 4
# 8 5
# 9 0

# %%
for i, idx in enumerate(it):
    print(i,idx)

# %%
1+1
# Out:
# 2

# %% [markdown]
# This is Resnet 34 SGD ls 1e-2 single GPU AFTER **UP**GRADE with sequencial sampling
# dumps/20190711_071657

# %%
# !cat ../dumps/20190711_071657/config_file.ini
# Out:
# [config]
# batch_size_test = 1024
# batch_size_train = 32
# batch_size_val = 1024
# best = 0
# cfg = None
# device = gpu
# dump_path = dumps/
# epochs = 10.0
# gpu_list =  0
# load = test_resnet_w_1em2
# lr = 0.01
# model =  resnet resnet34
# params =  num_input_channels=38 num_classes=3
# path = /fast_scratch/WatChMaL/data/IWCDmPMT/varyE/IWCDmPMT_varyE_100-1000MeV_300k_fmt.h5
# restore_state = None
# root = None
# shuffle = True
# subset = None
# tasks =  train valid
# test_split = 0.1
# val_split = 0.1
# worst = 0

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190711_071657/log_train.csv","/home/wfedorko/VAE/dumps/20190711_032216/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190711_071657/log_train.csv",window=100)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190711_071657/val_test.csv",window=40,sample_title="validation")

# %% [markdown]
# This is Resnet 34 SGD ls 1e-2 single GPU AFTER **UP**GRADE back to random sampling but many epochs
#
# dumps/20190712_001409

# %%
plot_utils.disp_learn_hist("/home/wfedorko/VAE/dumps/20190712_001409/log_train.csv","/home/wfedorko/VAE/dumps/20190712_001409/val_test.csv")
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190712_001409/log_train.csv",window=100)
plot_utils.disp_train_smoothed("/home/wfedorko/VAE/dumps/20190712_001409/val_test.csv",window=40,sample_title="validation")
