# %% [markdown]
# # VAE Event Reconstruction Analysis

# %%
# Python library and module imports
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import math
import h5py
import torch
from matplotlib.colors import LogNorm
import pandas as pd

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the custom plotting module
from plot_utils import plot_utils

# %% [markdown]
# # 10000 iterations

# %%
# Path to a sample event vs reconstruction file
np_arr_dir = "/home/akajal/WatChMaL/WatChMaL-VAE/USER/save_path_vae/data_description/"
np_arr_path = np_arr_dir + "20190609_181010/event_vs_recon_iteration_9999.npz"

# Load the numpy array
np_arr = np.load(np_arr_path)
np_event = np_arr["event"]
np_recon = np_arr["recon"]

# %%
plot_utils.plot_actual_vs_recon(np_event[12], np_recon[12], show_plot=True)

# %%
plot_utils.plot_actual_vs_recon_2(np_event[12], np_recon[12], show_plot=True)

# %% [markdown]
# # 20000 iterations

# %%
# Path to a sample event vs reconstruction file
np_arr_dir = "/home/akajal/WatChMaL/WatChMaL-VAE/USER/save_path_vae/data_description/"
np_arr_path = np_arr_dir + "20190609_181010/event_vs_recon_iteration_19999.npz"

# Load the numpy array
np_arr = np.load(np_arr_path)
np_event = np_arr["event"]
np_recon = np_arr["recon"]

# %%
plot_utils.plot_actual_vs_recon(np_event[9], np_recon[9], show_plot=True)

# %%
plot_utils.plot_actual_vs_recon_2(np_event[9], np_recon[9], show_plot=True)
