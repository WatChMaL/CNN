# %% [markdown]
# # September 09 - Training using the new dataset

# %%
# Imports
import sys
import os
import time

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Plotting import
import matplotlib.pyplot as plt

# Import the utils for plotting the metrics
from plot_utils import plot_utils
from plot_utils import notebook_utils_2

# %% [markdown]
# ## Plot the training of the VAE(128) with and without $\beta$ annealing on the fixed dataset

# %%
print("--------------------------\nWith the beta annealing :\n--------------------------")
run_id = "20190909_183138"
model_id = r"$\beta$-ENet(128)"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log, val_log = dump_dir + "log_train.csv", dump_dir + "log_val.csv"
    
# Plot training log
plot_utils.plot_vae_training([training_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)

# Plot validation log
plot_utils.plot_vae_training([val_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)
                             
print("--------------------------\nWithout the beta annealing :\n--------------------------")
run_id = "20190909_190620"
model_id = r"ENet(128)"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log, val_log = dump_dir + "log_train.csv", dump_dir + "log_val.csv"
    
# Plot training log
plot_utils.plot_vae_training([training_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)

# Plot validation log
plot_utils.plot_vae_training([val_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)
# Out:
# --------------------------
# With the beta annealing :
# --------------------------
# --------------------------
# Without the beta annealing :
# --------------------------

# %% [markdown]
# ## Plot the training of the PNF(128, 16) with and without $\beta$ annealing

# %%
print("--------------------------\nWithout the beta annealing :\n--------------------------")
run_id = "20190909_215637"
model_id = r"$\beta$-EnfNet(128,16)"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log, val_log = dump_dir + "log_train.csv", dump_dir + "log_val.csv"

# Plot training log
plot_utils.plot_vae_training([training_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)

print("--------------------------\nWithout the beta annealing :\n--------------------------")
run_id = "20190909_214639"
model_id = r"EnfNet(128,16)"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log, val_log = dump_dir + "log_train.csv", dump_dir + "log_val.csv"

# Plot training log
plot_utils.plot_vae_training([training_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)
# Out:
# --------------------------
# Without the beta annealing :
# --------------------------
# --------------------------
# Without the beta annealing :
# --------------------------
