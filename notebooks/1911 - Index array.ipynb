# %%
import numpy as np

# %%
a = np.load("/fast_scratch/WatChMaL/data/IWCD_fulltank_300_pe_idxs.npz")

# %%
print(a["train_idxs"].shape)
# Out:
# (4188774,)

# %%
print(a["val_idxs"].shape)
# Out:
# (837754,)

# %%
print(a["test_idxs"].shape)
# Out:
# (3351020,)
