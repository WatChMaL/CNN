# %% [markdown]
# # Fixing the ConvNets

# %%
# Imports
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the custom plotting module
from plot_utils import plot_utils

# %%
# Setup the paths to the log files

kazunet_log = "20190608_191126"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
kazunet_train_log = log_dir + kazunet_log + "/log_train.csv"
plot_utils.plot_training([kazunet_train_log],
                              ["KazuNetV2"],
                              {"KazuNetV2":["red","blue"]},
                              downsample_interval=100, show_plot=False)

# %%
# Setup the paths to the log files

convonlynet_log = "20190612_085128"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
convonlynet_train_log = log_dir + convonlynet_log + "/log_train.csv"
plot_utils.plot_training([convonlynet_train_log],
                              ["ConvOnlyNet"],
                              {"ConvOnlyNet":["red","blue"]},
                              downsample_interval=25, show_plot=False)

# %%
# Setup the paths to the log files

kazunet_log = "20190608_191126"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
kazunet_train_log = log_dir + kazunet_log + "/val_test.csv"
plot_utils.plot_training_validation([kazunet_train_log],
                              ["KazuNet"],
                              {"KazuNet":["red","blue"]},
                              downsample_interval=None, show_plot=False)

# %%
# Setup the paths to the log files

resnet_log = "20190609_033851"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
resnet_train_log = log_dir + resnet_log + "/log_train.csv"
plot_utils.plot_training_loss([resnet_train_log],
                              ["ResNet18 using SGD"],
                              {"ResNet18 using SGD":"red"},
                              downsample_interval=100, show_plot=True)
plot_utils.plot_training_accuracy([resnet_train_log],
                              ["ResNet18 using SGD"],
                              {"ResNet18 using SGD":"red"},
                              downsample_interval=100, show_plot=True)
# Out:
# Error. log path /home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/20190609_033851/log_train.csv does not exist
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-1f766b64bb46> in <module>
#       9                               ["ResNet18 using SGD"],
#      10                               {"ResNet18 using SGD":"red"},
# ---> 11                               downsample_interval=100, show_plot=True)
#      12 plot_utils.plot_training_accuracy([resnet_train_log],
#      13                               ["ResNet18 using SGD"],
#
# ~/WatChMaL/WatChMaL-VAE/plot_utils/plot_utils.py in plot_training_loss(log_paths, model_names, model_color_dict, downsample_interval, show_plot, save_path)
#     891     # Plot the values
#     892     for i, model_name in enumerate(model_names):
# ...

# %%
# Setup the paths to the log files

kazunet_log = "20190609_034536"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/USER/save_path_vae/data_description/"
kazunet_train_log = log_dir + kazunet_log + "/log_train.csv"
plot_utils.plot_training_loss([kazunet_train_log],
                              ["KazuNet using Adam, MaxPool"],
                              {"KazuNet using Adam, MaxPool":"red"},
                              downsample_interval=25, show_plot=True)
"""plot_utils.plot_training_accuracy([kazunet_train_log],
                              ["KazuNet using Adam, MaxPool"],
                              {"KazuNet using Adam, MaxPool":"red"},
                              downsample_interval=50, show_plot=True)"""
# Out:
# 5.828
# 6
# 6.870063
# 0.028
# 'plot_utils.plot_training_accuracy([kazunet_train_log],\n                              ["KazuNet using Adam, MaxPool"],\n                              {"KazuNet using Adam, MaxPool":"red"},\n                              downsample_interval=50, show_plot=True)'

# %%
# Setup the paths to the log files

Abhinet_log = "20190608_191140"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
Abhinet_train_log = log_dir + Abhinet_log + "/log_train.csv"
plot_utils.plot_training_loss([Abhinet_train_log],
                              ["AbhiNet"],
                              {"AbhiNet":"red"},
                              downsample_interval=500, show_plot=True)
plot_utils.plot_training_accuracy([Abhinet_train_log],
                              ["AbhiNet"],
                              {"AbhiNet":"red"},
                              downsample_interval=500, show_plot=True)
# Out:
# 10.0
# 26
# 1.173664
# 0.0012

# %%
# Setup the paths to the log files

densenet_log = "20190608_042113"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
densenet_train_log = log_dir + densenet_log + "/log_train.csv"
plot_utils.plot_training_loss([densenet_train_log],
                              ["DenseNet201"],
                              {"DenseNet201":"red"},
                              downsample_interval=300, show_plot=True)
plot_utils.plot_training_accuracy([densenet_train_log],
                              ["DenseNet201"],
                              {"DenseNet201":"red"},
                              downsample_interval=300, show_plot=True)
# Out:
# 10.0
# 7114
# 2.732022
# 0.316222

# %%
# Setup the paths to the log files

VAE2net_log = "20190602_233210"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/USER/save_path_vae/data_description/"
VAE2net_train_log = log_dir + VAE2net_log + "/log_train.csv"
plot_utils.plot_training_loss([VAE2net_train_log],
                              ["Old VAE2Net"],
                              {"Old VAE2Net":"red"},
                              downsample_interval=1000, show_plot=True)
# Out:
# 7.871911
# 0
# 8.3687
# 4.4e-05

# %%
# Setup the paths to the log files

kazunet_log = "20190608_015737"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/WatChMaL-VAE/save_path/data_description/"
kazunet_train_log = log_dir + kazunet_log + "/log_train.csv"
plot_utils.plot_training_loss([kazunet_train_log],
                              ["KazuNet (w/out softmax)"],
                              {"KazuNet (w/out softmax)":"red"},
                              downsample_interval=None, show_plot=True)
plot_utils.plot_training_accuracy([kazunet_train_log],
                              ["KazuNet (w/out softmax)"],
                              {"KazuNet (w/out softmax)":"red"},
                              downsample_interval=None, show_plot=True)
