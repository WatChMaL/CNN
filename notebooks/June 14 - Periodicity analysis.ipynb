# %% [markdown]
# # June 14 - Periodicity analysis

# %%
# Python library and module imports
import os
import sys
import matplotlib.pyplot as plt
import math
import h5py
import numpy as np
from matplotlib.colors import LogNorm
import pandas as pd
import random

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the custom plotting module
from plot_utils import plot_utils

# %%
# Setup the paths to the log files

log = "20190614_215921"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/VAE/dumps/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using Adam(lr=0.0001)"],
                              {"ResNet18 using Adam(lr=0.0001)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.5))

# %%
# Load the np array for the state_dict
state_dict_values = np.load(log_dir + log + "/optim_state_array.npy")
print(state_dict_values.shape)
# Out:
# (12500,)

# %%
print(state_dict_values[0].keys())
# Out:
# dict_keys(['step', 'exp_avg', 'exp_avg_sq'])

# %%
print(state_dict_values[1000]['step'])
# Out:
# 12500

# %%
# Setup the paths to the log files

log = "20190614_215612"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/VAE/dumps/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using Adagrad(lr=0.01)"],
                              {"ResNet18 using Adagrad(lr=0.01)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.5))

# %%
# Setup the paths to the log files

log = "20190614_225645"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/VAE/dumps/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["KazuNet using Adam(lr=0.0001)"],
                              {"KazuNet using Adam(lr=0.0001)":["red","blue"]},
                              downsample_interval=None, legend_loc=(0.82, 0.5))

# %%
# Setup the paths to the log files

log = "20190614_230253"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/VAE/dumps/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["KazuNet using Adam(lr=0.001)"],
                              {"KazuNet using Adam(lr=0.001)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.5))

# %%
# Setup the paths to the log files

log = "20190614_231000"

# Training log files for the models
log_dir =  "/home/akajal/WatChMaL/VAE/dumps/"
train_log = log_dir + log + "/log_train.csv"
plot_utils.plot_training([train_log],
                              ["ResNet18 using Adam(lr=0.001)"],
                              {"ResNet18 using Adam(lr=0.001)":["red","blue"]},
                              downsample_interval=32, legend_loc=(0.82, 0.5))
