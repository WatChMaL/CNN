# %% [markdown]
# # September 05 - Annealing the free energy

# %%
# Imports
import sys
import os

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the utils for plotting the metrics
from plot_utils import plot_utils
from plot_utils import notebook_utils_2

# %% [markdown]
# ## Plot the training of the VAE with 128 dimensions with and without the $\beta$ annealing

# %%
print("--------------------------\nWithout the beta annealing :\n--------------------------")
run_id = "20190904_185452"
model_id = "ENet(128)"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log, val_log = dump_dir + "log_train.csv", dump_dir + "log_val.csv"
    
# Plot training log
plot_utils.plot_vae_training([training_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)

# Plot validation log
plot_utils.plot_vae_training([val_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)

print("--------------------------\nWith the beta annealing :\n--------------------------")
run_id = "20190905_184206"
model_id = r"ENet-$\beta$(128)"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log, val_log = dump_dir + "log_train.csv", dump_dir + "log_val.csv"
    
# Plot training log
plot_utils.plot_vae_training([training_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)

# Plot validation log
plot_utils.plot_vae_training([val_log], [model_id], 
                             {model_id:["red", "blue"]},
                             downsample_interval=32,
                             legend_loc=(0.65,0.88),
                             show_plot=True)
# Out:
# --------------------------
# Without the beta annealing :
# --------------------------
# --------------------------
# With the beta annealing :
# --------------------------

# %% [markdown]
# ## Plot the training progess of the NF models using the $\beta$ annealing

# %%
# Using the absolute path
run_ids = ["20190905_184822", "20190905_184917", "20190905_185044", "20190905_185123", "20190905_185157"]
flow_depths = [16, 32, 64, 128, 256]

# %%
for run_id, flow_depth in zip(run_ids, flow_depths):
    dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
    training_log, val_log = dump_dir + "log_train.csv", dump_dir + "log_val.csv"
    
    print("--------------------------------------------------------------------")
    print("Plotting the training and validation log of NF with flow depth = {0}".format(flow_depth))
    print("--------------------------------------------------------------------")
    
    model_id = "EnfNet (" + str(flow_depth) + ")"
    
    # Plot training log
    plot_utils.plot_vae_training([training_log], [model_id], 
                                 {model_id:["red", "blue"]},
                                 downsample_interval=32,
                                 legend_loc=(0.65,0.88),
                                 show_plot=True)

    # Plot validation log
    plot_utils.plot_vae_training([val_log], [model_id], 
                                 {model_id:["red", "blue"]},
                                 downsample_interval=32,
                                 legend_loc=(0.65,0.88),
                                 show_plot=True)
# Out:
# --------------------------------------------------------------------
# Plotting the training and validation log of NF with flow depth = 16
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Plotting the training and validation log of NF with flow depth = 32
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Plotting the training and validation log of NF with flow depth = 64
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Plotting the training and validation log of NF with flow depth = 128
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# Plotting the training and validation log of NF with flow depth = 256
# --------------------------------------------------------------------
