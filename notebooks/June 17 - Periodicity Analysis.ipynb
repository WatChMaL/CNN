# %% [markdown]
# # June 17 - Periodicity Analysis

# %%
# Useful general imports

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import h5py

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if par_dir not in sys.path:
    sys.path.append(par_dir)
    
# Import the custom plotting module
from plot_utils import plot_utils

# %%
from matplotlib.colors import LogNorm
from scipy.stats import gaussian_kde
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

color_dict = {"gamma":"r", "e":"b", "mu":"g"}

# %%
# Using the absolute path
run_id = "20190617_221621"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"

# %%
# Load the numpy arrays into memory
softmaxes = np.load(dump_dir + "softmax.npy")
labels = np.load(dump_dir + "labels.npy")
predictions = np.load(dump_dir + "predictions.npy")
energies = np.load(dump_dir + "energies.npy")

# Check the shapes of the loaded arrays
print("softmaxes shape : ", softmaxes.shape)
print("labels shape : ", labels.shape)
print("predictions shape : ", predictions.shape)
print("energies shape : ", energies.shape)
# Out:
# softmaxes shape :  (10000, 3)
# labels shape :  (10000,)
# predictions shape :  (10000,)
# energies shape :  (10000,)

# %%
_, tpr_0, _, _, _, tpr_1, _, _ = plot_ROC_curve_one_vs_one(softmaxes, labels, energies, {"e":1, "mu":2},
                                                           "e", "mu",
                                                           min_energy=0, max_energy=1500, show_plot=True,
                                                           save_path=None)

# %%
print(tpr_0[:100])
# Out:
# [0.00000000e+00 6.00600601e-04 2.88288288e-02 3.00300300e-02
#  9.48948949e-02 9.60960961e-02 1.39939940e-01 1.41141141e-01
#  2.55255255e-01 2.56456456e-01 2.89489489e-01 2.89489489e-01
#  2.95495495e-01 2.95495495e-01 2.97897898e-01 2.97897898e-01
#  3.39339339e-01 3.39339339e-01 3.57357357e-01 3.57357357e-01
#  3.61561562e-01 3.62762763e-01 3.65765766e-01 3.65765766e-01
#  3.75975976e-01 3.75975976e-01 3.88588589e-01 3.88588589e-01
#  4.29429429e-01 4.29429429e-01 4.35435435e-01 4.35435435e-01
#  4.46846847e-01 4.46846847e-01 4.52852853e-01 4.52852853e-01
#  4.53453453e-01 4.53453453e-01 4.75075075e-01 4.75075075e-01
#  4.79279279e-01 4.79279279e-01 4.80480480e-01 4.80480480e-01
#  5.09309309e-01 5.09309309e-01 5.20720721e-01 5.20720721e-01
#  5.26726727e-01 5.26726727e-01 5.29729730e-01 5.29729730e-01
#  5.31531532e-01 5.31531532e-01 5.33933934e-01 5.33933934e-01
#  5.43543544e-01 5.43543544e-01 5.44744745e-01 5.44744745e-01
# ...

# %%
training_log = dump_dir + "log_train.csv"

# Plot using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=32, show_plot=True)

# %%
# Plot using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=None, show_plot=True)

# %%
# Validation log
val_log = dump_dir + "val_test.csv"

# Plot using the downsample intervals
plot_utils.plot_training([val_log], ["ResNet18 using Adam(lr=0.001)"], 
                         {"ResNet18 using Adam(lr=0.001)":["red", "blue"]},
                         downsample_interval=None, show_plot=True)

# %%
# Using the absolute path
run_id = "20190617_210204"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log = dump_dir + "log_train.csv"

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=None, show_plot=True)

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=32, show_plot=True)

# %%
# Using the absolute path
run_id = "20190617_133430"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log = dump_dir + "log_train.csv"

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=None, show_plot=True)

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=32, show_plot=True)

# %%
# Using the absolute path
run_id = "20190617_210956"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log = dump_dir + "log_train.csv"

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=None, show_plot=True)

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=32, show_plot=True)

# %%
# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=64, show_plot=True)

# %%
# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=128, legend_loc=(0.8,0.2), show_plot=True)

# %%
# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=256, legend_loc=(0.8,0.2), show_plot=True)

# %%
# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=512, legend_loc=(0.8,0.2), show_plot=True)

# %%
# Using the absolute path
run_id = "20190617_214810"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"
training_log = dump_dir + "log_train.csv"

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=None, show_plot=True)

# Plot without using the downsample intervals
plot_utils.plot_training([training_log], ["ResNet18 using Adam(lr=0.0001)"], 
                         {"ResNet18 using Adam(lr=0.0001)":["red", "blue"]},
                         downsample_interval=32, show_plot=True)

# %% [markdown]
# # Testing label_binarize

# %%
# Using the absolute path
run_id = "20190617_152841"
dump_dir = "/home/akajal/WatChMaL/VAE/dumps/" + run_id + "/"

# Load the numpy arrays into memory
softmaxes = np.load(dump_dir + "softmax.npy")
labels = np.load(dump_dir + "labels.npy")
predictions = np.load(dump_dir + "predictions.npy")
energies = np.load(dump_dir + "energies.npy")

# Check the shapes of the loaded arrays
print("softmaxes shape : ", softmaxes.shape)
print("labels shape : ", labels.shape)
print("predictions shape : ", predictions.shape)
print("energies shape : ", energies.shape)
# Out:
# softmaxes shape :  (5000, 3)
# labels shape :  (5000,)
# predictions shape :  (5000,)
# energies shape :  (5000,)

# %%
# Plot the energy distribution
plot_event_energy_distribution(energies, labels, {"gamma":0, "e":1, "mu":2},
                                          dset_type="validation", show_plot=True)

# %%
# Convert the energies
energies = convert_to_visible_energy(energies, labels)
plot_event_energy_distribution(energies, labels, {"gamma":0, "e":1, "mu":2},
                                          dset_type="validation", show_plot=True)

# %%
# Plot the confusion matrix
plot_confusion_matrix(labels, predictions, energies, ["gamma", "e", "mu"], show_plot=True)

# %%
# Plot the classifier response curve
plot_classifier_response(softmaxes, labels, energies, softmax_index_dict={"gamma":0, "e":1},
                                    event_dict={"gamma":0}, show_plot=True)
# Out:
# (array([157., 224., 123.,  80.,  59.,  57.,  39.,  31.,  21.,  17.,  25.,
#          24.,  22.,  16.,  17.,  16.,  11.,  14.,  11.,  10.,  14.,   9.,
#           7.,  15.,  17.,  14.,   6.,   7.,   8.,  12.,   1.,   8.,   5.,
#           3.,  11.,  11.,   5.,   5.,   7.,   5.,   3.,   7.,   8.,   6.,
#           2.,   2.,   7.,   9.,   6.,   5.,   6.,   4.,   7.,   2.,   7.,
#           9.,   4.,   4.,   5.,   4.,   2.,  10.,   4.,   3.,  11.,   6.,
#           6.,   3.,   6.,   6.,   8.,   6.,   5.,   5.,  10.,   6.,   7.,
#           6.,   6.,  10.,  13.,   6.,   9.,   7.,   7.,   7.,  10.,  10.,
#          10.,   9.,  17.,  18.,  16.,  13.,  17.,  24.,  16.,  22.,  26.,
#          31.]),
#  array([5.1262026e-04, 1.0493805e-02, 2.0474989e-02, 3.0456174e-02,
#         4.0437359e-02, 5.0418541e-02, 6.0399726e-02, 7.0380911e-02,
#         8.0362096e-02, 9.0343282e-02, 1.0032447e-01, 1.1030565e-01,
#         1.2028683e-01, 1.3026802e-01, 1.4024921e-01, 1.5023039e-01,
# ...

# %%
plot_classifier_response(softmaxes, labels, energies, softmax_index_dict={"gamma":0, "mu":2},
                                    event_dict={"gamma":0}, show_plot=True)
# Out:
# (array([1.691e+03, 3.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
plot_classifier_response(softmaxes, labels, energies, softmax_index_dict={"e":1, "mu":2},
                                    event_dict={"e":1}, show_plot=True)
# Out:
# (array([1.69e+03, 3.00e+00, 1.00e+00, 0.00e+00, 1.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00, 1.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
# ...

# %%
plot_ROC_curve_one_vs_one(softmaxes, labels, energies, {"e":1, "mu":2}, "e", "mu", show_plot=True)
# Out:
# (array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.88235294e-04,
#         5.88235294e-04, 5.88235294e-04, 5.88235294e-04, 5.88235294e-04,
#         5.88235294e-04, 5.88235294e-04, 5.88235294e-04, 1.17647059e-03,
#         1.17647059e-03, 1.76470588e-03, 1.76470588e-03, 1.76470588e-03,
#         1.76470588e-03, 1.76470588e-03, 1.76470588e-03, 2.35294118e-03,
#         2.35294118e-03, 2.94117647e-03, 2.94117647e-03, 3.52941176e-03,
#         3.52941176e-03, 4.11764706e-03, 4.11764706e-03, 4.70588235e-03,
#         4.70588235e-03, 5.29411765e-03, 5.29411765e-03, 5.88235294e-03,
#         5.88235294e-03, 6.47058824e-03, 6.47058824e-03, 7.05882353e-03,
#         7.05882353e-03, 7.64705882e-03, 7.64705882e-03, 8.82352941e-03,
#         8.82352941e-03, 1.00000000e-02, 1.00000000e-02, 1.17647059e-02,
#         1.17647059e-02, 1.29411765e-02, 1.29411765e-02, 1.35294118e-02,
# ...

# %%
plot_ROC_curve_one_vs_one(softmaxes, labels, energies, {"gamma":0, "e":1}, "gamma", "e", show_plot=True)
# Out:
# (array([0.       , 0.       , 0.       , ..., 0.9981982, 1.       ,
#         1.       ]),
#  array([0.00000000e+00, 6.11620795e-04, 4.89296636e-03, ...,
#         9.98165138e-01, 9.98165138e-01, 1.00000000e+00]),
#  array([1.9996803e+00, 9.9968028e-01, 9.9869412e-01, ..., 2.6719891e-03,
#         5.1262026e-04, 1.8908861e-04], dtype=float32),
#  0.6574475392824015,
#  array([0.00000000e+00, 6.11620795e-04, 1.22324159e-03, ...,
#         9.93883792e-01, 9.93883792e-01, 1.00000000e+00]),
#  array([0.       , 0.       , 0.       , ..., 0.9993994, 1.       ,
#         1.       ]),
#  array([1.9973257e+00, 9.9732566e-01, 9.9668354e-01, ..., 1.3733860e-03,
#         1.3658222e-03, 3.1588803e-04], dtype=float32),
#  0.6546697155871468)

# %%
plot_signal_efficiency(softmaxes, labels, energies, {"gamma":0, "e":1}, "e", "gamma",
                       avg_efficiencies=[0.2, 0.5, 0.8], show_plot=True)

# %%
plot_signal_efficiency(softmaxes, labels, energies, {"gamma":0, "e":1}, "gamma", "e",
                       avg_efficiencies=[0.2, 0.5, 0.8], show_plot=True)

# %%
plot_background_rejection(softmaxes, labels, energies, {"gamma":0, "e":1}, "gamma", "e",
                                    avg_efficiencies=[0.2, 0.5, 0.8], show_plot=True)
