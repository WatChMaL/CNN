# %%
import sys
import os
import random
import h5py
from collections import Counter
from progressbar import *
import re
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors

# Add the path to the parent directory to augment search for module
par_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

if par_dir not in sys.path:
    sys.path.append(par_dir)

from utils.plot_utils import *  
from io_utils.data_handling_hitarray_train import *
    
# %load_ext autoreload

# %%
index=999

# %% [markdown]
# ## Horizontal Flip

# %%
dset = WCH5DatasetT(['/fast_scratch/WatChMaL/data/IWCDmPMT_4pi_full_tank_pointnet.h5'], ['/fast_scratch/WatChMaL/data/IWCD_fulltank_300_pe_idxs.npz'], '/fast_scratch/WatChMaL/data/IWCDmPMT_4pi_fulltank_9M_norm_params/IWCDmPMT_4pi_fulltank_9M_trainval_norm_params.npz', chrg_norm='identity', time_norm='identity',
                                         transforms=['horizontal_flip'],shuffle=1, num_datasets=1, trainval_subset=None)
# Out:
# Loading training indices from:  /fast_scratch/WatChMaL/data/IWCD_fulltank_300_pe_idxs.npz

# %%
fig, ax = plt.subplots(1,1,figsize=(25,25),facecolor='w')
cmap = plt.cm.viridis
cmap.set_bad(color='black')
ev = dset[index][0]
ev = np.moveaxis(ev, 0,2)
a=get_plot_array(ev)
ax.imshow(a,
           origin="upper",
           cmap=cmap)
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(25,25),facecolor='w')
cmap = plt.cm.viridis
cmap.set_bad(color='black')
ev = dset[index][0]
ev = np.moveaxis(ev, 0,2)
a=get_plot_array(ev)
ax.imshow(a,
           origin="upper",
           cmap=cmap)
plt.show()

# %% [markdown]
# ## Vertical Flip

# %%
dset = WCH5DatasetT(['/fast_scratch/WatChMaL/data/IWCDmPMT_4pi_full_tank_pointnet.h5'], ['/fast_scratch/WatChMaL/data/IWCD_fulltank_300_pe_idxs.npz'], '/fast_scratch/WatChMaL/data/IWCDmPMT_4pi_fulltank_9M_norm_params/IWCDmPMT_4pi_fulltank_9M_trainval_norm_params.npz', chrg_norm='identity', time_norm='identity',
                                         transforms=['vertical_flip'],shuffle=1, num_datasets=1, trainval_subset=None)
# Out:
# Loading training indices from:  /fast_scratch/WatChMaL/data/IWCD_fulltank_300_pe_idxs.npz

# %%
fig, ax = plt.subplots(1,1,figsize=(25,25),facecolor='w')
cmap = plt.cm.viridis
cmap.set_bad(color='black')
ev = dset[index][0]
ev = np.moveaxis(ev, 0,2)
a=get_plot_array(ev)
ax.imshow(a,
           origin="upper",
           cmap=cmap)
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(25,25),facecolor='w')
cmap = plt.cm.viridis
cmap.set_bad(color='black')
ev = dset[index][0]
ev = np.moveaxis(ev, 0,2)
a=get_plot_array(ev)
ax.imshow(a,
           origin="upper",
           cmap=cmap)
plt.show()

# %% [markdown]
# ## Both

# %%
dset = WCH5DatasetT(['/fast_scratch/WatChMaL/data/IWCDmPMT_4pi_full_tank_pointnet.h5'], ['/fast_scratch/WatChMaL/data/IWCD_fulltank_300_pe_idxs.npz'], '/fast_scratch/WatChMaL/data/IWCDmPMT_4pi_fulltank_9M_norm_params/IWCDmPMT_4pi_fulltank_9M_trainval_norm_params.npz', chrg_norm='identity', time_norm='identity',
                                         transforms=['horizontal_flip', 'vertical_flip'],shuffle=1, num_datasets=1, trainval_subset=None)
# Out:
# Loading training indices from:  /fast_scratch/WatChMaL/data/IWCD_fulltank_300_pe_idxs.npz

# %%
fig, ax = plt.subplots(1,1,figsize=(25,25),facecolor='w')
cmap = plt.cm.viridis
cmap.set_bad(color='black')
ev = dset[index][0]
ev = np.moveaxis(ev, 0,2)
a=get_plot_array(ev)
ax.imshow(a,
           origin="upper",
           cmap=cmap)
plt.show()
